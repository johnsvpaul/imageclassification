# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense,Flatten

# %%
import pathlib

data_dir = pathlib.Path('dataset')

# %%
img_height,img_width=240,240
batch_size=32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  label_mode='categorical',  
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 291 files belonging to 3 classes.
# Using 233 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  label_mode='categorical',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 291 files belonging to 3 classes.
# Using 58 files for validation.

# %%
class_names=train_ds.class_names
print(class_names)
# Out:
# ['german_shepherd', 'husky', 'jack_russell']

# %%
#define model - get from keras/application

# %%
resnet_model = Sequential()

pretrained_model= tf.keras.applications.ResNet50(
                   include_top=False,
                   input_shape=(240,240,3),
                   pooling='avg',classes=3,
                   weights='imagenet')

for layer in pretrained_model.layers:
        layer.trainable=False

resnet_model.add(pretrained_model)

# %% [markdown]
# #Now, that we have imported a pre-trained model, we will also add a fully connected and output layer where actual learning can take place.

# %%
resnet_model.add(Flatten()) #flatten to 1D
resnet_model.add(Dense(512, activation='relu'))
resnet_model.add(Dense(3, activation='softmax'))#output layer

# %%
resnet_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 512)               1049088
#
#  dense_3 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 24,638,339
# Trainable params: 1,050,627
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %% [markdown]
# #The key point to note over here is that the total number of parameters in the Resnet50 model is 24 million. But the trainable parameters are only 1 million.

# %%
resnet_model.compile(optimizer=Adam(),loss='categorical_crossentropy',metrics=['accuracy'])

hist = resnet_model.fit(train_ds, validation_data=val_ds, epochs=20)
# Out:
# Epoch 1/20
# 2022-05-20 19:01:34.292071: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 8/8 [==============================] - ETA: 0s - loss: 1.4596 - accuracy: 0.5579
# 2022-05-20 19:01:37.427699: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 8/8 [==============================] - 5s 344ms/step - loss: 1.4596 - accuracy: 0.5579 - val_loss: 0.3777 - val_accuracy: 0.8793
# Epoch 2/20
# 8/8 [==============================] - 2s 206ms/step - loss: 0.1137 - accuracy: 0.9528 - val_loss: 0.2733 - val_accuracy: 0.8966
# Epoch 3/20
# 8/8 [==============================] - 2s 202ms/step - loss: 0.0432 - accuracy: 0.9914 - val_loss: 0.2359 - val_accuracy: 0.9138
# Epoch 4/20
# 8/8 [==============================] - 2s 210ms/step - loss: 0.0217 - accuracy: 0.9957 - val_loss: 0.2469 - val_accuracy: 0.9138
# Epoch 5/20
# 8/8 [==============================] - 2s 203ms/step - loss: 0.0119 - accuracy: 0.9957 - val_loss: 0.2050 - val_accuracy: 0.9138
# Epoch 6/20
# 8/8 [==============================] - 2s 213ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.2023 - val_accuracy: 0.9138
# Epoch 7/20
# 8/8 [==============================] - 2s 208ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.9138
# Epoch 8/20
# 8/8 [==============================] - 2s 209ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2183 - val_accuracy: 0.9138
# Epoch 9/20
# 8/8 [==============================] - 2s 204ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2205 - val_accuracy: 0.9138
# Epoch 10/20
# 8/8 [==============================] - 2s 246ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2226 - val_accuracy: 0.9138
# Epoch 11/20
# 8/8 [==============================] - 2s 206ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2276 - val_accuracy: 0.9138
# Epoch 12/20
# 8/8 [==============================] - 2s 258ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2305 - val_accuracy: 0.9138
# Epoch 13/20
# 8/8 [==============================] - 2s 216ms/step - loss: 9.3099e-04 - accuracy: 1.0000 - val_loss: 0.2326 - val_accuracy: 0.9138
# Epoch 14/20
# 8/8 [==============================] - 2s 219ms/step - loss: 8.5183e-04 - accuracy: 1.0000 - val_loss: 0.2352 - val_accuracy: 0.9138
# Epoch 15/20
# 8/8 [==============================] - 2s 216ms/step - loss: 8.0726e-04 - accuracy: 1.0000 - val_loss: 0.2398 - val_accuracy: 0.9138
# Epoch 16/20
# 8/8 [==============================] - 2s 221ms/step - loss: 7.4849e-04 - accuracy: 1.0000 - val_loss: 0.2430 - val_accuracy: 0.9138
# Epoch 17/20
# 8/8 [==============================] - 2s 217ms/step - loss: 6.9771e-04 - accuracy: 1.0000 - val_loss: 0.2455 - val_accuracy: 0.9138
# Epoch 18/20
# 8/8 [==============================] - 2s 227ms/step - loss: 6.4599e-04 - accuracy: 1.0000 - val_loss: 0.2481 - val_accuracy: 0.9138
# Epoch 19/20
# 8/8 [==============================] - 3s 292ms/step - loss: 6.0417e-04 - accuracy: 1.0000 - val_loss: 0.2508 - val_accuracy: 0.9138
# Epoch 20/20
# 8/8 [==============================] - 2s 260ms/step - loss: 5.6424e-04 - accuracy: 1.0000 - val_loss: 0.2528 - val_accuracy: 0.9138

# %% [markdown]
# Graph for 20 epochs

# %%
fig1 = plt.gcf()
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.axis(ymin=0.4,ymax=1.1)
plt.grid()
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
#Predictions

import cv2

image=cv2.imread('unseen/gs.jpg')
image_resized= cv2.resize(image, (img_height,img_width))
image=np.expand_dims(image_resized,axis=0)
#print(image.shape)

# %%
pred=resnet_model.predict(image)
print(pred)
# Out:
# 2022-05-20 19:04:08.797084: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [[9.7761625e-01 2.2370571e-02 1.3225883e-05]]

# %%
output_class=class_names[np.argmax(pred)]
print("The predicted class is", output_class)

PIL.Image.open('unseen/gs.jpg')
# Out:
# The predicted class is german_shepherd
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=333x500>
