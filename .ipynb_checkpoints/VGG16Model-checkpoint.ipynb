# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense,Flatten

# %%
import pathlib


data_dir = pathlib.Path('dataset')

# %%
img_height,img_width=240,240
batch_size=32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  label_mode='categorical',  
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 478 files belonging to 5 classes.
# Using 383 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  label_mode='categorical',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 478 files belonging to 5 classes.
# Using 95 files for validation.

# %%
class_names=train_ds.class_names
print(class_names)
# Out:
# ['german_shepherd', 'husky', 'jack_russell', 'labrador', 'pug']

# %%
#define model - get from keras/application

# %%
model = Sequential()


pretrained_model= tf.keras.applications.VGG16(
                    include_top=False,
                    weights="imagenet",
                    input_shape=(240,240,3),
                    pooling='avg',
                    classes=5,
                  
)
for layer in pretrained_model.layers:
        layer.trainable=False

model.add(pretrained_model)

# %% [markdown]
# #Now, that we have imported a pre-trained model, we will also add a fully connected and output layer where actual learning can take place.

# %%
model.add(Flatten()) #flatten to 1D
model.add(Dense(512, activation='relu'))
model.add(Dense(5, activation='softmax'))#output layer

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 512)               14714688
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dense_3 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 14,979,909
# Trainable params: 265,221
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# #The key point to note over here is that the total number of parameters in the Resnet50 model is 24 million. But the trainable parameters are only 1 million.

# %%
model.compile(optimizer=Adam(),loss='categorical_crossentropy',metrics=['accuracy'])

hist = model.fit(train_ds, validation_data=val_ds, epochs=20)
# Out:
# Epoch 1/20
# 2022-05-21 21:01:03.119883: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-05-21 21:01:03.119968: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 12/12 [==============================] - ETA: 0s - loss: 3.2424 - accuracy: 0.6084
# 2022-05-21 21:01:07.839983: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 12/12 [==============================] - 6s 408ms/step - loss: 3.2424 - accuracy: 0.6084 - val_loss: 1.1110 - val_accuracy: 0.8316
# Epoch 2/20
# 12/12 [==============================] - 5s 393ms/step - loss: 0.4845 - accuracy: 0.9373 - val_loss: 0.4423 - val_accuracy: 0.9368
# Epoch 3/20
# 12/12 [==============================] - 5s 392ms/step - loss: 0.0864 - accuracy: 0.9713 - val_loss: 0.3677 - val_accuracy: 0.9368
# Epoch 4/20
# 12/12 [==============================] - 5s 389ms/step - loss: 0.0393 - accuracy: 0.9869 - val_loss: 0.3231 - val_accuracy: 0.9368
# Epoch 5/20
# 12/12 [==============================] - 5s 401ms/step - loss: 0.0480 - accuracy: 0.9896 - val_loss: 0.1751 - val_accuracy: 0.9474
# Epoch 6/20
# 12/12 [==============================] - 5s 390ms/step - loss: 0.0061 - accuracy: 0.9948 - val_loss: 0.3598 - val_accuracy: 0.9263
# Epoch 7/20
# 12/12 [==============================] - 5s 391ms/step - loss: 0.0044 - accuracy: 0.9974 - val_loss: 0.2539 - val_accuracy: 0.9474
# Epoch 8/20
# 12/12 [==============================] - 5s 395ms/step - loss: 8.3348e-04 - accuracy: 1.0000 - val_loss: 0.2710 - val_accuracy: 0.9474
# Epoch 9/20
# 12/12 [==============================] - 5s 391ms/step - loss: 1.6272e-04 - accuracy: 1.0000 - val_loss: 0.2643 - val_accuracy: 0.9474
# Epoch 10/20
# 12/12 [==============================] - 5s 393ms/step - loss: 1.4133e-04 - accuracy: 1.0000 - val_loss: 0.2577 - val_accuracy: 0.9474
# Epoch 11/20
# 12/12 [==============================] - 5s 392ms/step - loss: 1.0830e-04 - accuracy: 1.0000 - val_loss: 0.2519 - val_accuracy: 0.9474
# Epoch 12/20
# 12/12 [==============================] - 5s 391ms/step - loss: 8.6073e-05 - accuracy: 1.0000 - val_loss: 0.2469 - val_accuracy: 0.9474
# Epoch 13/20
# 12/12 [==============================] - 5s 399ms/step - loss: 7.0462e-05 - accuracy: 1.0000 - val_loss: 0.2432 - val_accuracy: 0.9474
# Epoch 14/20
# 12/12 [==============================] - 5s 399ms/step - loss: 6.2613e-05 - accuracy: 1.0000 - val_loss: 0.2406 - val_accuracy: 0.9474
# Epoch 15/20
# 12/12 [==============================] - 5s 394ms/step - loss: 5.6160e-05 - accuracy: 1.0000 - val_loss: 0.2381 - val_accuracy: 0.9474
# Epoch 16/20
# 12/12 [==============================] - 5s 398ms/step - loss: 5.1867e-05 - accuracy: 1.0000 - val_loss: 0.2359 - val_accuracy: 0.9474
# Epoch 17/20
# 12/12 [==============================] - 5s 388ms/step - loss: 4.8780e-05 - accuracy: 1.0000 - val_loss: 0.2338 - val_accuracy: 0.9474
# Epoch 18/20
# 12/12 [==============================] - 5s 390ms/step - loss: 4.6248e-05 - accuracy: 1.0000 - val_loss: 0.2317 - val_accuracy: 0.9474
# Epoch 19/20
# 12/12 [==============================] - 5s 391ms/step - loss: 4.4136e-05 - accuracy: 1.0000 - val_loss: 0.2298 - val_accuracy: 0.9474
# Epoch 20/20
# 12/12 [==============================] - 5s 391ms/step - loss: 4.1875e-05 - accuracy: 1.0000 - val_loss: 0.2282 - val_accuracy: 0.9474

# %%
avg_train= np.mean(hist.history['accuracy']) 
print('The average accuracy for training set is: '+str(avg_train*100)+'%')
# Out:
# The average accuracy for training set is: 97.42819905281067%

# %%
avg_test= np.mean(hist.history['val_accuracy']) 
print('The average accuracy for test set is: '+str(avg_test*100)+'%')
# Out:
# The average accuracy for test set is: 93.8947394490242%

# %% [markdown]
# Graph for 20 epochs

# %%
fig1 = plt.gcf()
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.axis(ymin=0.4,ymax=1.1)
plt.grid()
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
#Predictions

import cv2
image_name = 'matthew'
image=cv2.imread('unseen/'+image_name+'.jpeg')
image_resized= cv2.resize(image, (img_height,img_width))
image=np.expand_dims(image_resized,axis=0)
#print(image.shape)
pred=model.predict(image)

output_class=class_names[np.argmax(pred)]
print("The predicted class is", output_class)

PIL.Image.open('unseen/'+image_name+'.jpeg')
# Out:
# 2022-05-22 01:06:19.391896: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# The predicted class is husky
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x320>

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 3>()
#       1 # model Architecture
#       2 Xception_model = Sequential()
# ----> 3 Xception_model.add(GlobalAveragePooling2D(input_shape=(train_Xception.shape[1:])))
#       4 Xception_model.add(Dense(133, activation='softmax'))
#       5 checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.Xception.hdf5', verbose = 0, save_best_only=True)
#
# NameError: name 'GlobalAveragePooling2D' is not defined
